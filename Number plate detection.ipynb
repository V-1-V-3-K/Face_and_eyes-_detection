# %% [markdown]
# # Library

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Import Image

# %%
img = cv2.imread("Images/audi.jpg")
plt.imshow(img)

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)

# %% [markdown]
# # Classifier

# %%
plate_classifier = cv2.CascadeClassifier("haar-cascade-files-master/haarcascade_russian_plate_number.xml")

# %% [markdown]
# # Detecting Number Plate

# %%
def detect_plate(img):
    plate_img = img.copy()
    
    plate_rects = plate_classifier.detectMultiScale(plate_img, 1.1, 1)
    
    for (x,y,w,h) in plate_rects:
        cv2.rectangle(plate_img,
                     (x,y),
                     (x+w,y+h),
                     (0,255,0),
                     5)
    return plate_img

# %%
result = detect_plate(fix_img)
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
plt.imshow(result)
